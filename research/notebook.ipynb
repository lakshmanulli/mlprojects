# %%
import os
import sys

# %%
import pandas as pd

# %%
data = pd.read_csv("D:/End to end projects/mlprojects/research/WineQT.csv")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
data.dropna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597

# %%
data.shape
# Out:
# (1143, 13)

# %%
import matplotlib.pyplot as plt

# %%
data.hist(bins=60, figsize=(25,20), color="green")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
X = data.drop(['quality','Id'],axis=1)

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
X.shape
# Out:
# (1143, 11)

# %%
y = data['quality']

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
X = data.drop(["quality"],axis=1)
y = data["quality"]

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol    Id
# 0         9.4     0
# 1         9.8     1
# 2         9.8     2
# 3         9.8     3
# 4         9.4     4
# ...       ...   ...
# 1138     11.0  1592
# 1139      9.5  1593
# 1140     10.5  1594
# 1141     11.2  1595
# 1142     10.2  1597
#
# [1143 rows x 12 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=40)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (800, 11)
# (343, 11)
# (800,)
# (343,)

# %%
from sklearn.linear_model import ElasticNet

# %%
lr = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)
lr.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.1, random_state=42)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)

    return rmse, mae, r2

# %%
predicted_value = lr.predict(X_test)

# %%
predicted_value
# Out:
# array([5.37080074, 5.72518507, 5.75436942, 5.420935  , 5.45522256,
#        5.23595182, 6.01290228, 5.93239385, 5.13460355, 5.62394563,
#        5.43473047, 5.5090529 , 6.33226135, 5.54985829, 5.71045289,
#        6.13008221, 5.3881565 , 5.62989608, 5.96581159, 5.71363465,
#        6.19234563, 5.37465301, 5.9749851 , 5.8910498 , 5.64240898,
#        5.34080546, 5.46771573, 5.40551884, 6.38832171, 7.29050144,
#        5.33835948, 5.8033268 , 6.02954868, 5.26491329, 5.85124605,
#        5.93127559, 5.40145356, 5.77948895, 6.23009106, 5.46399686,
#        5.36821205, 6.06314193, 5.88743059, 6.56509676, 5.10086433,
#        5.62786547, 5.44347209, 5.93973993, 5.9468308 , 5.15784655,
#        6.20719513, 5.34229799, 5.77793306, 6.35265188, 5.38994651,
#        5.77978679, 5.88932873, 5.36024856, 6.35190398, 6.17728416,
#        5.5146727 , 6.77199924, 5.27582414, 5.93255778, 6.32342488,
#        5.42445244, 5.23097349, 5.06964381, 5.87438009, 5.54219056,
#        5.17552073, 5.30767972, 5.51271427, 6.22931121, 5.71953226,
#        6.0032683 , 5.42071539, 5.95206343, 6.02282714, 6.15374695,
#        6.0198731 , 5.76622614, 6.28227515, 5.08589959, 5.75906131,
#        5.99057611, 5.9156832 , 5.53161851, 5.48666369, 5.22005692,
#        5.39766982, 5.61891754, 6.1021167 , 5.75368266, 5.51692279,
#        5.37447091, 5.25919985, 5.12358991, 5.65672034, 5.88848305,
#        5.3132057 , 5.53067471, 5.12637071, 5.53331364, 5.36461428,
#        5.29855022, 6.2942889 , 5.11772217, 5.50953511, 5.43189199,
#        6.07779623, 6.19517551, 5.03921592, 5.55935595, 5.55869392,
#        5.66688569, 5.62395429, 5.09919803, 5.68742394, 5.23249586,
#        5.52531681, 5.27346161, 5.75103837, 5.74005064, 5.61224163,
#        5.65598416, 5.70903189, 5.72749856, 6.12296282, 5.38115513,
#        5.93855356, 5.8550023 , 5.25669373, 6.36651006, 6.16829372,
#        5.44049572, 5.16808051, 5.19134996, 5.19789333, 5.78180902,
#        6.11725422, 5.29655377, 5.77879171, 6.05406463, 5.9607949 ,
#        5.8626011 , 6.06789547, 5.5261015 , 5.559376  , 5.22691374,
#        5.2546187 , 5.29820505, 5.17783592, 5.31684098, 5.27582516,
#        6.07622681, 5.65693317, 6.03667672, 5.51742225, 5.60059846,
#        4.99457694, 6.05319876, 5.5322985 , 6.00688906, 5.66669579,
#        5.39602033, 5.34399812, 6.07751838, 5.20821524, 5.06752557,
#        6.04281566, 5.99415715, 5.4375446 , 5.3263794 , 5.95602403,
#        5.7058199 , 5.9211299 , 5.63751911, 5.48796322, 5.5826026 ,
#        6.21501489, 5.97026885, 5.2361187 , 5.10160116, 5.94466437,
#        5.8425312 , 5.33289482, 5.38399825, 5.69560376, 5.37193943,
#        5.63207775, 5.89732525, 5.39485988, 6.53455591, 5.41077847,
#        5.7058199 , 6.60001492, 5.08666527, 6.5876114 , 5.41928818,
#        5.70323845, 5.06289102, 5.153632  , 5.92410627, 6.09619665,
#        5.34080546, 6.26810669, 5.20005048, 6.32184028, 5.78225386,
#        5.19086742, 5.84954088, 5.98718771, 5.730922  , 5.37457423,
#        5.51254774, 5.29986066, 5.61753646, 5.33996979, 5.33470071,
#        5.36743428, 5.65344228, 5.65465859, 6.29054204, 5.2808821 ,
#        5.46663736, 5.39373985, 5.51510634, 6.11300529, 6.0035114 ,
#        5.93742507, 5.49288611, 5.98757852, 5.06023666, 5.5826026 ,
#        5.35923132, 6.29699093, 5.61867047, 5.57569239, 5.42297532,
#        5.75784903, 5.81786153, 5.44176399, 5.60752194, 5.44306837,
#        6.35265188, 5.75548841, 6.20719513, 6.1703942 , 5.96556557,
#        5.22691374, 5.07341262, 5.38431218, 5.16307918, 5.30485159,
#        5.69273398, 6.13331996, 5.64526062, 5.44406328, 5.88408053,
#        5.98991043, 5.25085055, 6.10586825, 5.41202059, 5.97729859,
#        5.26137925, 5.26391713, 5.36191243, 5.77838104, 6.18618489,
#        5.45740493, 5.31684098, 5.50926161, 5.88347587, 5.74941732,
#        6.06444301, 5.97535345, 5.61626564, 5.78215471, 5.73784463,
#        5.88035698, 5.15316813, 5.65873026, 5.32804278, 5.9156832 ,
#        5.66433313, 5.8117808 , 5.72933777, 5.39078646, 6.27396788,
#        5.43947419, 5.26241738, 5.61764327, 5.64759878, 5.44399831,
#        5.57929832, 5.9938351 , 6.18036072, 5.16613245, 5.987456  ,
#        5.38828209, 5.51170499, 5.68974257, 5.35837476, 5.3338077 ,
#        5.69401369, 6.38834157, 5.80596002, 6.14061539, 5.31277655,
#        5.30531648, 5.72705384, 5.8294135 , 5.50385586, 5.94868714,
#        5.46711365, 5.94594227, 5.65360732, 6.44263511, 5.30355845,
#        5.93924462, 6.06085648, 5.31466694, 5.9156832 , 5.72518507,
#        5.4057344 , 5.40305488, 5.34661583, 5.68369113, 5.55781888,
#        5.94559988, 5.62786547, 5.94466437, 5.29647585, 6.11505147,
#        5.48005466, 5.13329641, 6.23231954, 5.17920438, 5.49933362,
#        5.27432143, 5.55677813, 5.32194596])

# %%
(rmse, mae, r2) = eval_metrics(y_test, predicted_value)

# %%
print("rmse = ", rmse)
print("mae = ", mae)
print("r2 = ", r2)
# Out:
# rmse =  0.6770477830945065
# mae =  0.5325679726461486
# r2 =  0.26817618627411743
